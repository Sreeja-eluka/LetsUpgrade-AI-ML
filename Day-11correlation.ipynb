# %%
import pandas as pd

df = pd.read_csv('general_data.csv')

df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.dropna()
# Out:
#       Age  Attrition  BusinessTravel              Department  \
# 0      51          0               1                   Sales
# 1      31          1               2  Research & Development
# 2      32          0               2  Research & Development
# 3      38          0               0  Research & Development
# 4      32          0               1  Research & Development
# ...   ...        ...             ...                     ...
# 4404   29          0               1                   Sales
# 4405   42          0               1  Research & Development
# 4406   29          0               1  Research & Development
# 4407   25          0               1  Research & Development
# 4408   42          0               1                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# 1                   10          1  Life Sciences              1           2
# ...

# %%
df["Attrition"].replace(to_replace=("No","Yes"),value=(0,1),inplace=True)
df
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# **1.CORRELATION BETWEEN ATTRITION AND AGE**

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(df.Attrition,df.Age)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.Age)
# Out:
# -0.15920500686577965 1.996801615886744e-26
# negatively correlated to each other
#  Null hypothesis rejected

# %% [markdown]
# **2.CORRELATION BETWEEN ATTRITION AND TRAVEL FREQUENTLY**

# %%
df["BusinessTravel"].replace(to_replace=("Non-Travel","Travel_Rarely","Travel_Frequently"),value=(0,1,2),inplace=True)
df
# Out:
#       Age  Attrition  BusinessTravel              Department  \
# 0      51          0               1                   Sales
# 1      31          1               2  Research & Development
# 2      32          0               2  Research & Development
# 3      38          0               0  Research & Development
# 4      32          0               1  Research & Development
# ...   ...        ...             ...                     ...
# 4405   42          0               1  Research & Development
# 4406   29          0               1  Research & Development
# 4407   25          0               1  Research & Development
# 4408   42          0               1                   Sales
# 4409   40          0               1  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# 1                   10          1  Life Sciences              1           2
# ...

# %%
stats,p=pearsonr(df.Attrition,df.BusinessTravel)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.BusinessTravel)
# Out:
# 0.12700648315243618 2.536639653019909e-17
# positively correlated with each other
#  Null hypothesis rejected

# %% [markdown]
# **3.CORRELATION BETWEEN ATTRITION AND DistanceFromHome**

# %%
stats,p=pearsonr(df.Attrition,df.DistanceFromHome)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.DistanceFromHome)
# Out:
# -0.00973014101017966 0.5182860428050771
# negatively correlated to each other
# Null hypothesis accepted

# %% [markdown]
# **4.CORRELATION BETWEEN ATTRITION AND Education**

# %%
stats,p=pearsonr(df.Attrition,df.Education)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.Education)
# Out:
# -0.015111167710968711 0.3157293177118575
# negatively correlated to each other
# Null hypothesis accepted

# %% [markdown]
# **5.CORRELATION BETWEEN ATTRITION AND Gender**

# %%
df["Gender"].replace(to_replace=("Female","Male"),value=(0,1),inplace=True)
df
# Out:
#       Age  Attrition  BusinessTravel              Department  \
# 0      51          0               1                   Sales
# 1      31          1               2  Research & Development
# 2      32          0               2  Research & Development
# 3      38          0               0  Research & Development
# 4      32          0               1  Research & Development
# ...   ...        ...             ...                     ...
# 4405   42          0               1  Research & Development
# 4406   29          0               1  Research & Development
# 4407   25          0               1  Research & Development
# 4408   42          0               1                   Sales
# 4409   40          0               1  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# 1                   10          1  Life Sciences              1           2
# ...

# %%
stats,p=pearsonr(df.Attrition,df.Gender)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.Gender)
# Out:
# 0.01812507887701024 0.22881970951795952
# positively correlated with each other
# Null hypothesis accepted

# %% [markdown]
# **6.CORRELATION BETWEEN ATTRITION AND PERCENTSALARYHIKE**

# %%
stats,p=pearsonr(df.Attrition,df.PercentSalaryHike)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.PercentSalaryHike)
# Out:
# 0.03253259489105351 0.030743386433355353
# positively correlated with each other
#  Null hypothesis rejected

# %% [markdown]
# **7.CORRELATION BETWEEN ATTRITION AND TrainingTimesLastYear**

# %%
# df.duplicated
stats,p=pearsonr(df.Attrition,df.TrainingTimesLastYear)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.TrainingTimesLastYear)
# Out:
# -0.04943057624425501 0.0010247061915362814
# negatively correlated to each other
#  Null hypothesis rejected

# %% [markdown]
# **8.CORRELATION BETWEEN ATTRITION AND YEARSAT COMPANY**

# %%
stats,p=pearsonr(df.Attrition,df.YearsAtCompany)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.YearsAtCompany)
# Out:
# -0.1343922139899772 3.1638831224877484e-19
# negatively correlated to each other
#  Null hypothesis rejected

# %% [markdown]
# **9.CORRELATION BETWEEN ATTRITION AND YEARS SINCE LAST PROMOTION**

# %%
stats,p=pearsonr(df.Attrition,df.YearsSinceLastPromotion)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.YearsSinceLastPromotion)
# Out:
# -0.03301877514258434 0.028330336189396753
# negatively correlated to each other
#  Null hypothesis rejected

# %% [markdown]
# **10.CORRELATION BETWEEN ATTRITION AND YEARS WITH CURRENT MANAGER**

# %%
stats,p=pearsonr(df.Attrition,df.YearsWithCurrManager)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(df.Attrition,df.YearsWithCurrManager)
# Out:
# -0.15619931590162842 1.7339322652900218e-25
# negatively correlated to each other
#  Null hypothesis rejected

# %% [markdown]
# **11.CORRELATION BETWEEN ATTRITION AND TOTAL WORKING YEARS**

# %%
#df["TotalWorkingYears"].isnull().sum()
dff=df.dropna()
stats,p=pearsonr(dff.Attrition,dff.TotalWorkingYears)
print(stats,p)
if(stats==0):
            print("no correlation")
elif(stats>0):
             print("positively correlated with each other")
else:
    print("negatively correlated to each other")
if(p<0.05):
    print(" Null hypothesis rejected")
else:
    print("Null hypothesis accepted")
import matplotlib.pyplot as plt
plt.scatter(dff.Attrition,dff.TotalWorkingYears)
# Out:
# -0.16966991684723917 1.1645434967091854e-29
# negatively correlated to each other
#  Null hypothesis rejected

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import tree
from sklearn import preprocessing

# %%
df=pd.read_csv("general_data.csv")
df.head(2)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
df['NumCompaniesWorked'] = df['NumCompaniesWorked'].fillna(df['NumCompaniesWorked'].mean())
df.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          9
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
le=preprocessing.LabelEncoder()
df["Attrition"]= le.fit_transform(df["Attrition"])
df["BusinessTravel"]=le.fit_transform(df["BusinessTravel"])
df["Department"]=le.fit_transform(df["Department"])
df["EducationField"]=le.fit_transform(df["EducationField"])
df["Gender"]=le.fit_transform(df["Gender"])
df["MaritalStatus"]=le.fit_transform(df["MaritalStatus"])
df["JobRole"]=le.fit_transform(df["JobRole"])
df
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               2           2                 6          2
# 1      31          1               1           1                10          1
# 2      32          0               1           1                17          4
# 3      38          0               0           1                 2          5
# 4      32          0               2           1                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4404   29          0               2           2                 4          3
# 4405   42          0               2           1                 5          4
# 4406   29          0               2           1                 2          4
# 4407   25          0               2           1                25          2
# 4408   42          0               2           2                18          2
#
# ...

# %% [markdown]
# **dropping irrelevant columns**

# %%
df = df.drop(['EmployeeCount','EmployeeID', 'Over18','StandardHours'], axis=1)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               2           2                 6          2
# 1   31          1               1           1                10          1
# 2   32          0               1           1                17          4
# 3   38          0               0           1                 2          5
# 4   32          0               2           1                10          1
#
#    EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  \
# 0               1       0         1        0              1         131160
# 1               1       0         1        6              2          41890
# 2               4       1         4        7              1         193280
# 3               1       1         3        1              1          83210
# 4               3       1         1        7              2          23420
#
# ...

# %% [markdown]
# **splitting Dataset**

# %%
y=df.iloc[:,1:2]
y.head(4)
# Out:
#    Attrition
# 0          0
# 1          1
# 2          0
# 3          0

# %%
x=df.drop(columns=["Attrition"])
x.head(2)
# Out:
#    Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51               2           2                 6          2
# 1   31               1           1                10          1
#
#    EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  \
# 0               1       0         1        0              1         131160
# 1               1       0         1        6              2          41890
#
#    NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0                 1.0                 11                 0                1.0
# 1                 0.0                 23                 1                6.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      6               1                        0
# 1                      3               5                        1
#
#    YearsWithCurrManager
# 0                     0
# 1                     4

# %% [markdown]
# **TRAINING THE MODEL USING DECISION TREE**

# %%
tree_model=tree.DecisionTreeClassifier()
tree_model.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
tree_model.score(x,y)
# Out:
# 1.0

# %% [markdown]
# with respect to score the model seems overfitting as the accuracy is 100%

# %% [markdown]
# **HERE ATTRITION IS DEPENDENT VARIABLE TO FIND IMPORTANT INDEPENEDENT VARIABLE WE WILL PERFORM RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=1000,max_features=2,oob_score=True)

# %%
rf_model.fit(x,y)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features=2,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf_model.oob_score_
# Out:
# 1.0

# %% [markdown]
# **FINDING IMPORTANT VARIABLES:**

# %%
a = ['Age', 'BusinessTravel', 'Department', 'DistanceFromHome','Education', 'EducationField', 'Gender', 'JobLevel', 'JobRole',
       'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked','PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion','YearsWithCurrManager']
for feature,imp in zip(a,rf_model.feature_importances_):
    print(feature,"\t\t :",imp)
# Out:
# Age 		 : 0.0966557839778677
# BusinessTravel 		 : 0.02780825672750069
# Department 		 : 0.02581589580937535
# DistanceFromHome 		 : 0.07010672942469874
# Education 		 : 0.04080960148277402
# EducationField 		 : 0.04125330692760844
# Gender 		 : 0.018370476030678425
# JobLevel 		 : 0.03733773590685114
# JobRole 		 : 0.055498062399259765
# MaritalStatus 		 : 0.04000789609930984
# MonthlyIncome 		 : 0.09408985908359374
# NumCompaniesWorked 		 : 0.056005145539298105
# PercentSalaryHike 		 : 0.06585271354456984
# StockOptionLevel 		 : 0.03417899695256563
# TotalWorkingYears 		 : 0.08509722492418936
# TrainingTimesLastYear 		 : 0.04468905406014326
# YearsAtCompany 		 : 0.06832710177428489
# YearsSinceLastPromotion 		 : 0.04368133751133952
# YearsWithCurrManager 		 : 0.05441482182409166

# %% [markdown]
# **CONCLUSION:**<br>
# from above we can see that <br>
# Age,DistanceFromHome,MonthlyIncome,TotalworkingYears,YearsAtCompany,PercentSalaryHike has higher impact on Attrition

# %% [markdown]
# **TAKING INDEPENDENT VARIABLES WHICH ARE  IMPORTANT**

# %%
imp=df[['Age','DistanceFromHome','MonthlyIncome','TotalWorkingYears','YearsAtCompany','PercentSalaryHike']]
imp.head(3)
# Out:
#    Age  DistanceFromHome  MonthlyIncome  TotalWorkingYears  YearsAtCompany  \
# 0   51                 6         131160                1.0               1
# 1   31                10          41890                6.0               5
# 2   32                17         193280                5.0               5
#
#    PercentSalaryHike
# 0                 11
# 1                 23
# 2                 15

# %% [markdown]
# **DESICION TREE:**

# %%
model = tree.DecisionTreeClassifier(max_depth=12)
model.fit(imp,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=12, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# **SCORE:**

# %%
model.score(imp,y)
# Out:
# 0.9450124971597365

# %% [markdown]
# **score is optimum now!!**

# %%
impf=["Age","DistanceFromHome","MonthlyIncome","TotalWorkingYears","YearsAtCompany","PercentSalaryHike"]
from sklearn.tree import export_text
r=export_text(model,feature_names=impf)
print(r)
# Out:
# |--- TotalWorkingYears <= 1.50
# |   |--- Age <= 33.50
# |   |   |--- MonthlyIncome <= 112610.00
# |   |   |   |--- MonthlyIncome <= 23140.00
# |   |   |   |   |--- PercentSalaryHike <= 12.50
# |   |   |   |   |   |--- DistanceFromHome <= 6.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- DistanceFromHome >  6.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- PercentSalaryHike >  12.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- MonthlyIncome >  23140.00
# |   |   |   |   |--- Age <= 23.50
# |   |   |   |   |   |--- Age <= 18.50
# |   |   |   |   |   |   |--- DistanceFromHome <= 4.00
# |   |   |   |   |   |   |   |--- PercentSalaryHike <= 20.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- PercentSalaryHike >  20.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DistanceFromHome >  4.00
# |   |   |   |   |   |   |   |--- class: 0
# ...

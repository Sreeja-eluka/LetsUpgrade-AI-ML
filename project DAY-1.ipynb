# %%
import os 
import sys
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from scipy.io import loadmat
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# import pyod packages and methods

# %%
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# import performance metrics package

# %%
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %% [markdown]
# define data file and read X and y

# %%
mat_file_list=['arrhythmia.mat','cardio.mat','glass.mat','ionosphere.mat',
              'letter.mat','lympho.mat','mnist.mat','musk.mat','optdigits.mat'
              ,'pendigits.mat','pima.mat','satellite.mat','satimage-2.mat',
              'shuttle.mat','vertebral.mat','vowels.mat','wbc.mat']
mat_file_list
# Out:
# ['arrhythmia.mat',
#  'cardio.mat',
#  'glass.mat',
#  'ionosphere.mat',
#  'letter.mat',
#  'lympho.mat',
#  'mnist.mat',
#  'musk.mat',
#  'optdigits.mat',
#  'pendigits.mat',
#  'pima.mat',
#  'satellite.mat',
#  'satimage-2.mat',
#  'shuttle.mat',
#  'vertebral.mat',
#  'vowels.mat',
#  'wbc.mat']

# %%
data=loadmat('cardio.mat')
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#          -0.28978574, -0.49329397],
#         [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#          -0.25638541, -0.49329397],
#         [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#          -0.25638541,  1.14001753],
#         ...,
#         [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#           0.24461959, -0.49329397],
#         [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#           0.14441859, -0.49329397],
#         [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#           3.58465295, -0.49329397]]),
#  'y': array([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])}

# %%
len(data)
# Out:
# 5

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
data.values()
# Out:
# dict_values([b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC', '1.0', [], array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#         -0.28978574, -0.49329397],
#        [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#         -0.25638541, -0.49329397],
#        [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#         -0.25638541,  1.14001753],
#        ...,
#        [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#          0.24461959, -0.49329397],
#        [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#          0.14441859, -0.49329397],
#        [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#          3.58465295, -0.49329397]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]])])

# %%
type(data['X']),data['X'].shape
# Out:
# (numpy.ndarray, (1831, 21))

# %%
type(data['y']),data['y'].shape
# Out:
# (numpy.ndarray, (1831, 1))

# %% [markdown]
# define nine outliers to be compared

# %%
df_columns=['Data','#Samples','#Dimeensions','Outlier Prec',
           'ABOD','CBLOF','FB','IForest','KNN','LOF','MCD',
           'OCSVM','PCA']

# %% [raw]
# **ROC PERFORMANCE EVALUATION TABLE**

# %%
roc_df = pd.DataFrame(columns= df_columns)
roc_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, #Dimeensions, Outlier Prec, ABOD, CBLOF, FB, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# PRECISION_N_SCORES -Performance evaluation table

# %%
prn_df =pd.DataFrame(columns=df_columns)
prn_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, #Dimeensions, Outlier Prec, ABOD, CBLOF, FB, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# TIME DATAFRAME

# %%
time_df =pd.DataFrame(columns=df_columns)
time_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, #Dimeensions, Outlier Prec, ABOD, CBLOF, FB, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# EXPLORING ALL MAT FILES

# %%
#Exploring/Accessing all mat files
from time import time
random_state = np.random.RandomState(42)


for mat_file in mat_file_list:
    print("\n... Processing", mat_file, "...")
    mat = loadmat(os.path.join(mat_file))
    
    X = mat["X"]
    y = mat["y"].ravel()
    
    outliers_fraction = np.count_nonzero(y)/len(y)
    outliers_percentage = round(outliers_fraction*100, ndigits=4)
    
    #construct containers for saving results
    roc_list = [mat_file[:-4],X.shape[0],X.shape[1], outliers_percentage]
    prn_list = [mat_file[:-4],X.shape[0],X.shape[1], outliers_percentage]
    time_list = [mat_file[:-4],X.shape[0],X.shape[1], outliers_percentage]
    
    #60% data for training and 40% for testing
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state = 2)
    
    # STandardaizing data for preprocessing
    X_train_norm,  X_test_norm = standardizer(X_train,X_test)
    
    classifiers = {
                   "Angle based outlier detector(ABOD)":ABOD(contamination = outliers_fraction), #contamination based on what factors the data is considered as outliers
                   "Cluster-based Loacl Outlier Factor":CBLOF(contamination = outliers_fraction,check_estimator= False, random_state=random_state),
                   "Feature Bagging":FeatureBagging(contamination = outliers_fraction,random_state=random_state),
                   "Histogram base outlier detection": HBOS(contamination = outliers_fraction),
                   "Isolation Forest": IForest(contamination = outliers_fraction,random_state=random_state),
                   "k Nearest Neighbours (kNN)": KNN(contamination = outliers_fraction),
                   "Local Outlier Factor(LOF)": LOF(contamination = outliers_fraction),
                   "Minimun Covariance Determinant (MCD)": MCD(contamination = outliers_fraction, random_state=random_state),
                   "One-Class SVM (OCSVM)": OCSVM(contamination = outliers_fraction),
                   "Principal Component Analysis": PCA(contamination = outliers_fraction,random_state=random_state)
                  }
                   
    for clf_name,clf in classifiers.items():
        t0 =time ()
        clf.fit(X_train_norm)
        test_scores = clf.decision_function(X_test_norm)
        t1 = time()
        duration = round(t1-t0, ndigits=4)
        time_list.append(duration)
                        
        roc = round(roc_auc_score(y_test,test_scores),ndigits = 4)
        prn = round(precision_n_scores(y_test,test_scores),ndigits = 4)
                        
        print("{clf_name} ROC:{roc}, precision @ rank n:{prn}, execution time: {duration}s".
                              format(clf_name=clf_name, roc =roc, prn = prn, duration = duration))
        roc_list.append(roc)
        prn_list.append(prn)
                        
    temp_df = pd.DataFrame(time_list).transpose()
    temp_df_columns = df_columns
    time_df = pd.concat([time_df,temp_df],axis=0)
    
    temp_df = pd.DataFrame(roc_list).transpose()
    temp_df_columns = df_columns
    roc_df = pd.concat([roc_df,temp_df],axis=0)
    
    temp_df = pd.DataFrame(prn_list).transpose()
    temp_df_columns = df_columns
    prn_df = pd.concat([prn_df,temp_df],axis=0)
# Out:
# ... Processing arrhythmia.mat ...
# Angle based outlier detector(ABOD) ROC:0.7246, precision @ rank n:0.2857, execution time: 0.1637s
# Cluster-based Loacl Outlier Factor ROC:0.7283, precision @ rank n:0.2857, execution time: 0.1358s
# Feature Bagging ROC:0.712, precision @ rank n:0.2857, execution time: 0.5761s
# Histogram base outlier detection ROC:0.8077, precision @ rank n:0.4643, execution time: 0.0543s
# Isolation Forest ROC:0.7972, precision @ rank n:0.4286, execution time: 0.4295s
# k Nearest Neighbours (kNN) ROC:0.7148, precision @ rank n:0.2857, execution time: 0.0893s
# Local Outlier Factor(LOF) ROC:0.7171, precision @ rank n:0.3214, execution time: 0.0703s
# Minimun Covariance Determinant (MCD) ROC:0.725, precision @ rank n:0.3214, execution time: 0.6803s
# One-Class SVM (OCSVM) ROC:0.7124, precision @ rank n:0.2857, execution time: 0.0583s
# Principal Component Analysis ROC:0.7134, precision @ rank n:0.2857, execution time: 0.06s
#
# ... Processing cardio.mat ...
# Angle based outlier detector(ABOD) ROC:0.5928, precision @ rank n:0.275, execution time: 0.4373s
# Cluster-based Loacl Outlier Factor ROC:0.7221, precision @ rank n:0.3, execution time: 0.1646s
# Feature Bagging ROC:0.6003, precision @ rank n:0.2, execution time: 0.7797s
# Histogram base outlier detection ROC:0.8556, precision @ rank n:0.525, execution time: 0.012s
# Isolation Forest ROC:0.9243, precision @ rank n:0.55, execution time: 0.4088s
# k Nearest Neighbours (kNN) ROC:0.7663, precision @ rank n:0.3875, execution time: 0.1366s
# Local Outlier Factor(LOF) ROC:0.6062, precision @ rank n:0.2, execution time: 0.0951s
# Minimun Covariance Determinant (MCD) ROC:0.8685, precision @ rank n:0.45, execution time: 0.5835s
# One-Class SVM (OCSVM) ROC:0.9404, precision @ rank n:0.55, execution time: 0.0832s
# Principal Component Analysis ROC:0.9542, precision @ rank n:0.6375, execution time: 0.0034s
#
# ... Processing glass.mat ...
# Angle based outlier detector(ABOD) ROC:0.8571, precision @ rank n:0.2857, execution time: 0.0562s
# Cluster-based Loacl Outlier Factor ROC:0.8373, precision @ rank n:0.1429, execution time: 0.0598s
# Feature Bagging ROC:0.8571, precision @ rank n:0.1429, execution time: 0.036s
# Histogram base outlier detection ROC:0.7288, precision @ rank n:0.0, execution time: 0.0s
# Isolation Forest ROC:0.745, precision @ rank n:0.1429, execution time: 0.2907s
# k Nearest Neighbours (kNN) ROC:0.8427, precision @ rank n:0.1429, execution time: 0.008s
# Local Outlier Factor(LOF) ROC:0.8499, precision @ rank n:0.1429, execution time: 0.004s
# Minimun Covariance Determinant (MCD) ROC:0.7975, precision @ rank n:0.1429, execution time: 0.0304s
# One-Class SVM (OCSVM) ROC:0.5714, precision @ rank n:0.1429, execution time: 0.0s
# Principal Component Analysis ROC:0.642, precision @ rank n:0.1429, execution time: 0.0s
#
# ... Processing ionosphere.mat ...
# Angle based outlier detector(ABOD) ROC:0.9312, precision @ rank n:0.8305, execution time: 0.0979s
# Cluster-based Loacl Outlier Factor ROC:0.9103, precision @ rank n:0.8644, execution time: 0.06s
# Feature Bagging ROC:0.9132, precision @ rank n:0.7966, execution time: 0.0738s
# Histogram base outlier detection ROC:0.6263, precision @ rank n:0.5085, execution time: 0.008s
# Isolation Forest ROC:0.8597, precision @ rank n:0.7119, execution time: 0.2893s
# k Nearest Neighbours (kNN) ROC:0.937, precision @ rank n:0.8983, execution time: 0.016s
# Local Outlier Factor(LOF) ROC:0.9155, precision @ rank n:0.7627, execution time: 0.0081s
# Minimun Covariance Determinant (MCD) ROC:0.9427, precision @ rank n:0.8983, execution time: 0.0601s
# One-Class SVM (OCSVM) ROC:0.8584, precision @ rank n:0.7627, execution time: 0.0026s
# Principal Component Analysis ROC:0.828, precision @ rank n:0.661, execution time: 0.004s
#
# ... Processing letter.mat ...
# Angle based outlier detector(ABOD) ROC:0.8804, precision @ rank n:0.3778, execution time: 0.3541s
# Cluster-based Loacl Outlier Factor ROC:0.7622, precision @ rank n:0.2667, execution time: 0.0901s
# Feature Bagging ROC:0.8536, precision @ rank n:0.3556, execution time: 0.7634s
# Histogram base outlier detection ROC:0.5871, precision @ rank n:0.0889, execution time: 0.012s
# Isolation Forest ROC:0.6212, precision @ rank n:0.1333, execution time: 0.4742s
# k Nearest Neighbours (kNN) ROC:0.861, precision @ rank n:0.3111, execution time: 0.1202s
# Local Outlier Factor(LOF) ROC:0.8484, precision @ rank n:0.3556, execution time: 0.0839s
# Minimun Covariance Determinant (MCD) ROC:0.8006, precision @ rank n:0.2, execution time: 1.2145s
# One-Class SVM (OCSVM) ROC:0.6162, precision @ rank n:0.1778, execution time: 0.0804s
# Principal Component Analysis ROC:0.5385, precision @ rank n:0.1111, execution time: 0.004s
#
# ... Processing lympho.mat ...
# Angle based outlier detector(ABOD) ROC:0.8973, precision @ rank n:0.75, execution time: 0.0376s
# Cluster-based Loacl Outlier Factor ROC:0.9821, precision @ rank n:0.75, execution time: 0.044s
# Feature Bagging ROC:0.9821, precision @ rank n:0.75, execution time: 0.0465s
# Histogram base outlier detection ROC:1.0, precision @ rank n:1.0, execution time: 0.0022s
# Isolation Forest ROC:1.0, precision @ rank n:1.0, execution time: 0.2933s
# k Nearest Neighbours (kNN) ROC:0.9598, precision @ rank n:0.75, execution time: 0.004s
# Local Outlier Factor(LOF) ROC:0.9821, precision @ rank n:0.75, execution time: 0.0s
# Minimun Covariance Determinant (MCD) ROC:0.8884, precision @ rank n:0.75, execution time: 0.0271s
# One-Class SVM (OCSVM) ROC:0.9821, precision @ rank n:0.75, execution time: 0.0s
# Principal Component Analysis ROC:0.9911, precision @ rank n:0.75, execution time: 0.0025s
#
# ... Processing mnist.mat ...
# Angle based outlier detector(ABOD) ROC:0.7949, precision @ rank n:0.3946, execution time: 6.5853s
# Cluster-based Loacl Outlier Factor ROC:0.8162, precision @ rank n:0.3679, execution time: 1.0878s
# Feature Bagging ROC:0.7412, precision @ rank n:0.3679, execution time: 41.8202s
# Histogram base outlier detection ROC:0.5885, precision @ rank n:0.1237, execution time: 0.052s
# Isolation Forest ROC:0.8214, precision @ rank n:0.2977, execution time: 2.1489s
# k Nearest Neighbours (kNN) ROC:0.856, precision @ rank n:0.4381, execution time: 6.0434s
# Local Outlier Factor(LOF) ROC:0.7227, precision @ rank n:0.3545, execution time: 5.7829s
# Minimun Covariance Determinant (MCD) ROC:0.8541, precision @ rank n:0.3077, execution time: 2.7639s
# One-Class SVM (OCSVM) ROC:0.864, precision @ rank n:0.4281, execution time: 4.2535s
# Principal Component Analysis ROC:0.8635, precision @ rank n:0.4114, execution time: 0.162s
#
# ... Processing musk.mat ...
# Angle based outlier detector(ABOD) ROC:0.1312, precision @ rank n:0.0588, execution time: 2.0859s
# Cluster-based Loacl Outlier Factor ROC:1.0, precision @ rank n:1.0, execution time: 0.3669s
# Feature Bagging ROC:0.4629, precision @ rank n:0.1471, execution time: 11.3629s
# Histogram base outlier detection ROC:1.0, precision @ rank n:0.9697, execution time: 0.0561s
# Isolation Forest ROC:0.9995, precision @ rank n:0.9118, execution time: 1.2871s
# k Nearest Neighbours (kNN) ROC:0.7337, precision @ rank n:0.1471, execution time: 1.6712s
# Local Outlier Factor(LOF) ROC:0.4544, precision @ rank n:0.1176, execution time: 1.534s
# Minimun Covariance Determinant (MCD) ROC:0.9999, precision @ rank n:0.9706, execution time: 11.9137s
# One-Class SVM (OCSVM) ROC:1.0, precision @ rank n:1.0, execution time: 1.2224s
# Principal Component Analysis ROC:0.9999, precision @ rank n:0.9706, execution time: 0.1477s
#
# ... Processing optdigits.mat ...
# Angle based outlier detector(ABOD) ROC:0.4287, precision @ rank n:0.0, execution time: 2.5323s
# Cluster-based Loacl Outlier Factor ROC:0.7617, precision @ rank n:0.0, execution time: 0.4923s
# Feature Bagging ROC:0.4415, precision @ rank n:0.0448, execution time: 11.3368s
# Histogram base outlier detection ROC:0.8656, precision @ rank n:0.2537, execution time: 0.032s
# Isolation Forest ROC:0.655, precision @ rank n:0.0299, execution time: 0.922s
# k Nearest Neighbours (kNN) ROC:0.3853, precision @ rank n:0.0, execution time: 1.6157s
# Local Outlier Factor(LOF) ROC:0.4537, precision @ rank n:0.0448, execution time: 1.5025s
# Minimun Covariance Determinant (MCD) ROC:0.3681, precision @ rank n:0.0, execution time: 1.2872s
# One-Class SVM (OCSVM) ROC:0.5012, precision @ rank n:0.0, execution time: 1.4184s
# Principal Component Analysis ROC:0.5033, precision @ rank n:0.0, execution time: 0.0501s
#
# ... Processing pendigits.mat ...
# Angle based outlier detector(ABOD) ROC:0.689, precision @ rank n:0.0882, execution time: 1.6201s
# Cluster-based Loacl Outlier Factor ROC:0.8356, precision @ rank n:0.25, execution time: 0.2229s
# Feature Bagging ROC:0.4959, precision @ rank n:0.0588, execution time: 4.0437s
# Histogram base outlier detection ROC:0.9243, precision @ rank n:0.3235, execution time: 0.008s
# Isolation Forest ROC:0.9422, precision @ rank n:0.3971, execution time: 0.6217s
# k Nearest Neighbours (kNN) ROC:0.7524, precision @ rank n:0.1029, execution time: 0.5739s
# Local Outlier Factor(LOF) ROC:0.4846, precision @ rank n:0.0441, execution time: 0.5352s
# Minimun Covariance Determinant (MCD) ROC:0.8448, precision @ rank n:0.1176, execution time: 2.0516s
# One-Class SVM (OCSVM) ROC:0.9332, precision @ rank n:0.4118, execution time: 0.9364s
# Principal Component Analysis ROC:0.9343, precision @ rank n:0.3824, execution time: 0.0082s
#
# ... Processing pima.mat ...
# Angle based outlier detector(ABOD) ROC:0.6924, precision @ rank n:0.5243, execution time: 0.1504s
# Cluster-based Loacl Outlier Factor ROC:0.6751, precision @ rank n:0.4951, execution time: 0.0879s
# Feature Bagging ROC:0.6127, precision @ rank n:0.3981, execution time: 0.0889s
# Histogram base outlier detection ROC:0.6672, precision @ rank n:0.4854, execution time: 0.004s
# Isolation Forest ROC:0.6588, precision @ rank n:0.4369, execution time: 0.3385s
# k Nearest Neighbours (kNN) ROC:0.6913, precision @ rank n:0.4951, execution time: 0.0343s
# Local Outlier Factor(LOF) ROC:0.6563, precision @ rank n:0.4369, execution time: 0.012s
# Minimun Covariance Determinant (MCD) ROC:0.6636, precision @ rank n:0.4854, execution time: 0.0474s
# One-Class SVM (OCSVM) ROC:0.5832, precision @ rank n:0.4272, execution time: 0.012s
# Principal Component Analysis ROC:0.5857, precision @ rank n:0.4369, execution time: 0.0s
#
# ... Processing satellite.mat ...
# Angle based outlier detector(ABOD) ROC:0.5758, precision @ rank n:0.4067, execution time: 1.7556s
# Cluster-based Loacl Outlier Factor ROC:0.7986, precision @ rank n:0.6435, execution time: 0.4685s
# Feature Bagging ROC:0.5676, precision @ rank n:0.4127, execution time: 6.9283s
# Histogram base outlier detection ROC:0.7737, precision @ rank n:0.5909, execution time: 0.016s
# Isolation Forest ROC:0.7102, precision @ rank n:0.5706, execution time: 0.8207s
# k Nearest Neighbours (kNN) ROC:0.7013, precision @ rank n:0.5275, execution time: 0.9692s
# Local Outlier Factor(LOF) ROC:0.5689, precision @ rank n:0.4103, execution time: 0.9053s
# Minimun Covariance Determinant (MCD) ROC:0.8182, precision @ rank n:0.7069, execution time: 2.2629s
# One-Class SVM (OCSVM) ROC:0.6827, precision @ rank n:0.5598, execution time: 1.3119s
# Principal Component Analysis ROC:0.6104, precision @ rank n:0.494, execution time: 0.0233s
#
# ... Processing satimage-2.mat ...
# Angle based outlier detector(ABOD) ROC:0.8338, precision @ rank n:0.1875, execution time: 1.6607s
# Cluster-based Loacl Outlier Factor ROC:0.9999, precision @ rank n:0.9375, execution time: 0.3081s
# Feature Bagging ROC:0.4576, precision @ rank n:0.0938, execution time: 5.3415s
# Histogram base outlier detection ROC:0.9865, precision @ rank n:0.6562, execution time: 0.0163s
# Isolation Forest ROC:0.9972, precision @ rank n:0.875, execution time: 0.7006s
# k Nearest Neighbours (kNN) ROC:0.9644, precision @ rank n:0.4062, execution time: 0.8657s
# Local Outlier Factor(LOF) ROC:0.4468, precision @ rank n:0.0938, execution time: 0.7252s
# Minimun Covariance Determinant (MCD) ROC:0.9949, precision @ rank n:0.625, execution time: 1.9997s
# One-Class SVM (OCSVM) ROC:0.9998, precision @ rank n:0.9375, execution time: 1.0662s
# Principal Component Analysis ROC:0.99, precision @ rank n:0.8125, execution time: 0.0159s
#
# ... Processing shuttle.mat ...
# Angle based outlier detector(ABOD) ROC:0.6157, precision @ rank n:0.1819, execution time: 13.1617s
# Cluster-based Loacl Outlier Factor ROC:0.664, precision @ rank n:0.2326, execution time: 1.1538s
# Feature Bagging ROC:0.4715, precision @ rank n:0.079, execution time: 40.3906s
# Histogram base outlier detection ROC:0.9856, precision @ rank n:0.9806, execution time: 0.0181s
# Isolation Forest ROC:0.9958, precision @ rank n:0.9486, execution time: 3.4099s
# k Nearest Neighbours (kNN) ROC:0.6551, precision @ rank n:0.2062, execution time: 7.0776s
# Local Outlier Factor(LOF) ROC:0.5277, precision @ rank n:0.1594, execution time: 8.8536s
# Minimun Covariance Determinant (MCD) ROC:0.9889, precision @ rank n:0.7362, execution time: 11.989s
# One-Class SVM (OCSVM) ROC:0.9896, precision @ rank n:0.9514, execution time: 44.6615s
# Principal Component Analysis ROC:0.9879, precision @ rank n:0.9486, execution time: 0.0342s
#
# ... Processing vertebral.mat ...
# Angle based outlier detector(ABOD) ROC:0.358, precision @ rank n:0.0, execution time: 0.0718s
# Cluster-based Loacl Outlier Factor ROC:0.385, precision @ rank n:0.0, execution time: 0.078s
# Feature Bagging ROC:0.3232, precision @ rank n:0.0, execution time: 0.0462s
# Histogram base outlier detection ROC:0.351, precision @ rank n:0.0714, execution time: 0.0s
# Isolation Forest ROC:0.3981, precision @ rank n:0.0714, execution time: 0.346s
# k Nearest Neighbours (kNN) ROC:0.3667, precision @ rank n:0.0, execution time: 0.012s
# Local Outlier Factor(LOF) ROC:0.2892, precision @ rank n:0.0, execution time: 0.004s
# Minimun Covariance Determinant (MCD) ROC:0.4051, precision @ rank n:0.0, execution time: 0.0437s
# One-Class SVM (OCSVM) ROC:0.4199, precision @ rank n:0.0, execution time: 0.0s
# Principal Component Analysis ROC:0.4408, precision @ rank n:0.1429, execution time: 0.0035s
#
# ... Processing vowels.mat ...
# Angle based outlier detector(ABOD) ROC:0.9667, precision @ rank n:0.5263, execution time: 0.3723s
# Cluster-based Loacl Outlier Factor ROC:0.913, precision @ rank n:0.2105, execution time: 0.1432s
# Feature Bagging ROC:0.9603, precision @ rank n:0.3684, execution time: 0.3997s
# Histogram base outlier detection ROC:0.7511, precision @ rank n:0.1579, execution time: 0.004s
# Isolation Forest ROC:0.8054, precision @ rank n:0.3684, execution time: 0.4236s
# k Nearest Neighbours (kNN) ROC:0.9669, precision @ rank n:0.6316, execution time: 0.0839s
# Local Outlier Factor(LOF) ROC:0.9595, precision @ rank n:0.4737, execution time: 0.036s
# Minimun Covariance Determinant (MCD) ROC:0.7261, precision @ rank n:0.0, execution time: 0.9492s
# One-Class SVM (OCSVM) ROC:0.8672, precision @ rank n:0.4211, execution time: 0.062s
# Principal Component Analysis ROC:0.7061, precision @ rank n:0.2105, execution time: 0.0s
#
# ... Processing wbc.mat ...
# Angle based outlier detector(ABOD) ROC:0.8776, precision @ rank n:0.0, execution time: 0.1178s
# Cluster-based Loacl Outlier Factor ROC:0.8313, precision @ rank n:0.2, execution time: 0.076s
# Feature Bagging ROC:0.8816, precision @ rank n:0.2, execution time: 0.0898s
# Histogram base outlier detection ROC:0.9429, precision @ rank n:0.4, execution time: 0.0103s
# Isolation Forest ROC:0.8558, precision @ rank n:0.2, execution time: 0.4075s
# k Nearest Neighbours (kNN) ROC:0.8816, precision @ rank n:0.2, execution time: 0.02s
# Local Outlier Factor(LOF) ROC:0.8898, precision @ rank n:0.2, execution time: 0.008s
# Minimun Covariance Determinant (MCD) ROC:0.917, precision @ rank n:0.4, execution time: 0.0784s
# One-Class SVM (OCSVM) ROC:0.8776, precision @ rank n:0.2, execution time: 0.008s
# Principal Component Analysis ROC:0.8231, precision @ rank n:0.2, execution time: 0.004s

# %% [raw]
# ROC DATAFRAME

# %%
roc_df
# Out:
#              0      1    2        3       4       5       6       7       8  \
# 0   arrhythmia    452  274  14.6018  0.7246  0.7283   0.712  0.8077  0.7972
# 0       cardio   1831   21   9.6122  0.5928  0.7221  0.6003  0.8556  0.9243
# 0        glass    214    9   4.2056  0.8571  0.8373  0.8571  0.7288   0.745
# 0   ionosphere    351   33  35.8974  0.9312  0.9103  0.9132  0.6263  0.8597
# 0       letter   1600   32     6.25  0.8804  0.7622  0.8536  0.5871  0.6212
# ..         ...    ...  ...      ...     ...     ...     ...     ...     ...
# 0   satimage-2   5803   36   1.2235  0.8338  0.9999  0.4576  0.9865  0.9972
# 0      shuttle  49097    9   7.1511  0.6157   0.664  0.4715  0.9856  0.9958
# 0    vertebral    240    6     12.5   0.358   0.385  0.3232   0.351  0.3981
# 0       vowels   1456   12   3.4341  0.9667   0.913  0.9603  0.7511  0.8054
# 0          wbc    378   30   5.5556  0.8776  0.8313  0.8816  0.9429  0.8558
#
#          9  ... CBLOF Data   FB IForest  KNN  LOF  MCD OCSVM Outlier Prec  PCA
# 0   0.7148  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.7663  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.8427  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0    0.937  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0    0.861  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# ..     ...  ...   ...  ...  ...     ...  ...  ...  ...   ...          ...  ...
# 0   0.9644  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.6551  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.3667  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.9669  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.8816  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
#
# [65 rows x 27 columns]

# %%
prn_df
# Out:
#              0      1    2        3       4       5       6       7       8  \
# 0   arrhythmia    452  274  14.6018  0.2857  0.2857  0.2857  0.4643  0.4286
# 0       cardio   1831   21   9.6122   0.275     0.3     0.2   0.525    0.55
# 0        glass    214    9   4.2056  0.2857  0.1429  0.1429       0  0.1429
# 0   ionosphere    351   33  35.8974  0.8305  0.8644  0.7966  0.5085  0.7119
# 0       letter   1600   32     6.25  0.3778  0.2667  0.3556  0.0889  0.1333
# ..         ...    ...  ...      ...     ...     ...     ...     ...     ...
# 0   satimage-2   5803   36   1.2235  0.1875  0.9375  0.0938  0.6562   0.875
# 0      shuttle  49097    9   7.1511  0.1819  0.2326   0.079  0.9806  0.9486
# 0    vertebral    240    6     12.5       0       0       0  0.0714  0.0714
# 0       vowels   1456   12   3.4341  0.5263  0.2105  0.3684  0.1579  0.3684
# 0          wbc    378   30   5.5556       0     0.2     0.2     0.4     0.2
#
#          9  ... CBLOF Data   FB IForest  KNN  LOF  MCD OCSVM Outlier Prec  PCA
# 0   0.2857  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.3875  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.1429  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.8983  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.3111  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# ..     ...  ...   ...  ...  ...     ...  ...  ...  ...   ...          ...  ...
# 0   0.4062  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.2062  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0        0  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.6316  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0      0.2  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
#
# [65 rows x 27 columns]

# %%
time_df
# Out:
#              0      1    2        3        4       5        6       7       8  \
# 0   arrhythmia    452  274  14.6018   4.4181  2.7594   0.6101  1.7519  0.5789
# 0       cardio   1831   21   9.6122   0.4035  0.1632   0.7619  0.0101  0.3635
# 0        glass    214    9   4.2056   0.0599  0.0559   0.0479   0.004  0.3156
# 0   ionosphere    351   33  35.8974   0.0959  0.0679   0.0882   0.012  0.3543
# 0       letter   1600   32     6.25   0.3893  0.0919   0.7204   0.008  0.3795
# ..         ...    ...  ...      ...      ...     ...      ...     ...     ...
# 0   satimage-2   5803   36   1.2235   1.6607  0.3081   5.3415  0.0163  0.7006
# 0      shuttle  49097    9   7.1511  13.1617  1.1538  40.3906  0.0181  3.4099
# 0    vertebral    240    6     12.5   0.0718   0.078   0.0462       0   0.346
# 0       vowels   1456   12   3.4341   0.3723  0.1432   0.3997   0.004  0.4236
# 0          wbc    378   30   5.5556   0.1178   0.076   0.0898  0.0103  0.4075
#
#          9  ... CBLOF Data   FB IForest  KNN  LOF  MCD OCSVM Outlier Prec  PCA
# 0   0.0901  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.1358  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0    0.008  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0     0.02  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.1355  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# ..     ...  ...   ...  ...  ...     ...  ...  ...  ...   ...          ...  ...
# 0   0.8657  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   7.0776  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0    0.012  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0   0.0839  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
# 0     0.02  ...   NaN  NaN  NaN     NaN  NaN  NaN  NaN   NaN          NaN  NaN
#
# [65 rows x 27 columns]
